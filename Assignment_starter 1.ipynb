# %%
import pandas as pd
data_df=pd.read_csv("DLCF FUTA Aspirants Bio-Data & Advisory Form (Responses) - Form Responses 1.csv")
data_df
# Out:
#               Timestamp                   Email Address  First Name  \
# 0   10/10/2020 22:26:42      akinwamideelijah@gmail.com      Elijah
# 1    10/11/2020 8:59:25  ajayisegunsamuel2002@gmail.com    Olusegun
# 2   10/11/2020 10:25:57       akintundeakinba@gmail.com  Akinbamowo
# 3   10/11/2020 15:09:46    johnsonchidinma304@gmail.com     Johnson
# 4   10/11/2020 16:31:26         arewaolawale2@gmail.com       Arewa
# ..                  ...                             ...         ...
# 66   1/13/2021 10:20:15      adeoluwatomisin2@gmail.com     Adeniyi
# 67   1/13/2021 10:35:06       ogunkandevictor@gmail.com   Ogunkande
# 68   1/13/2021 10:47:07         Petertomywa72@gmail.com   Ogunmola
# 69   1/13/2021 16:50:00       Basaumariam0000@gmail.com      Mariam
# 70   1/14/2021 19:57:35         Hosannahomole@gmail.com    Hosannah
#
#             Other Names State of Residence     Sex  \
# 0            Akinwamide               Ogun    Male
# ...

# %%
data_df[data_df["Email Address"]=="hopeikuesan@gmail.com"]
# Out:
#               Timestamp          Email Address First Name Other Names  \
# 22  10/30/2020 17:36:32  hopeikuesan@gmail.com   Ikuesan        Hope
#
#    State of Residence     Sex  Mobile Number (Preferably WhatsApp)  \
# 22             Lagos   Female                           7017955647
#
#                 Denomination School/Faculty Applied For  \
# 22  Deeper Life Bible Church   School of Sciences (SOS)
#
#    Course/Department Applied For  Jamb Score  \
# 22                   Statistics          294
#
#                     Jamb Subject Combination  \
# 22  English, Mathematics, Chemistry, Physics
#
#    Did you register for the upcoming NECO exams scheduled to start October?  \
# 22                                                 No
#
#    Have you completed the online registration for the Post Utme Exam?  \
# 22                                                Yes
#
#    What challenge(s) are/were you faced with during the cause of application and registration?  \
# ...

# %%
data_df["Day"]=pd.DatetimeIndex(data_df.Timestamp).day
data_df["Month"]=pd.DatetimeIndex(data_df.Timestamp).month
data_df["Year"]=pd.DatetimeIndex(data_df.Timestamp).year
data_df["Hour"]=pd.DatetimeIndex(data_df.Timestamp).hour
data_df["Minute"]=pd.DatetimeIndex(data_df.Timestamp).minute
data_df["Second"]=pd.DatetimeIndex(data_df.Timestamp).second
data_df
# Out:
#               Timestamp                   Email Address  First Name  \
# 0   10/10/2020 22:26:42      akinwamideelijah@gmail.com      Elijah
# 1    10/11/2020 8:59:25  ajayisegunsamuel2002@gmail.com    Olusegun
# 2   10/11/2020 10:25:57       akintundeakinba@gmail.com  Akinbamowo
# 3   10/11/2020 15:09:46    johnsonchidinma304@gmail.com     Johnson
# 4   10/11/2020 16:31:26         arewaolawale2@gmail.com       Arewa
# ..                  ...                             ...         ...
# 66   1/13/2021 10:20:15      adeoluwatomisin2@gmail.com     Adeniyi
# 67   1/13/2021 10:35:06       ogunkandevictor@gmail.com   Ogunkande
# 68   1/13/2021 10:47:07         Petertomywa72@gmail.com   Ogunmola
# 69   1/13/2021 16:50:00       Basaumariam0000@gmail.com      Mariam
# 70   1/14/2021 19:57:35         Hosannahomole@gmail.com    Hosannah
#
#             Other Names State of Residence     Sex  \
# 0            Akinwamide               Ogun    Male
# ...

# %%
data_df.drop("Timestamp",axis=1,inplace=True)

# %%
data_df
# Out:
#                      Email Address  First Name          Other Names  \
# 0       akinwamideelijah@gmail.com      Elijah           Akinwamide
# 1   ajayisegunsamuel2002@gmail.com    Olusegun               Samuel
# 2        akintundeakinba@gmail.com  Akinbamowo            Akintunde
# 3     johnsonchidinma304@gmail.com     Johnson         Chidinma joy
# 4          arewaolawale2@gmail.com       Arewa              Olawale
# ..                             ...         ...                  ...
# 66      adeoluwatomisin2@gmail.com     Adeniyi  Oluwatomisin kayode
# 67       ogunkandevictor@gmail.com   Ogunkande         Victor segun
# 68         Petertomywa72@gmail.com   Ogunmola                Peter
# 69       Basaumariam0000@gmail.com      Mariam             Precious
# 70         Hosannahomole@gmail.com    Hosannah               Korede
#
#    State of Residence     Sex  Mobile Number (Preferably WhatsApp)  \
# 0                Ogun    Male                           9093934248
# ...

# %%
data_df["State of Residence"].unique()
# Out:
# array(['Ogun', 'Lagos', 'Ondo', 'Kwara state', 'OGUN', 'Lagos state',
#        'Oyo', 'ONDO STATE', 'LAGOS STATE', 'Osun state', 'Ondo state',
#        'Ifo ogun state', 'Lagos ', 'Oyo state ', 'Ekiti', 'Kwara',
#        'Ogun state ', 'Kogi ', 'Ogum', 'Abuja', 'Ekiti state',
#        'Ondo state Akure ', 'Ekiti State ', 'Oyo state', 'Osun',
#        'Oke aro akure', 'Tipper Garage mowe-ofada, ogun state', 'Ilesha',
#        'Benin Republic', 'Ondostate', 'Rivers State', 'Kogi'],
#       dtype=object)

# %%
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ondo state":["Ondo"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ondo state Akure":["Ondo"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ondostate":["Ondo"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ondostate":["Ondo"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Oke aro akure":["Ondo"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"ONDO STATE":["Ondo"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ondo state Akure ":["Ondo"]})

data_df
# Out:
#                      Email Address  First Name          Other Names  \
# 0       akinwamideelijah@gmail.com      Elijah           Akinwamide
# 1   ajayisegunsamuel2002@gmail.com    Olusegun               Samuel
# 2        akintundeakinba@gmail.com  Akinbamowo            Akintunde
# 3     johnsonchidinma304@gmail.com     Johnson         Chidinma joy
# 4          arewaolawale2@gmail.com       Arewa              Olawale
# ..                             ...         ...                  ...
# 66      adeoluwatomisin2@gmail.com     Adeniyi  Oluwatomisin kayode
# 67       ogunkandevictor@gmail.com   Ogunkande         Victor segun
# 68         Petertomywa72@gmail.com   Ogunmola                Peter
# 69       Basaumariam0000@gmail.com      Mariam             Precious
# 70         Hosannahomole@gmail.com    Hosannah               Korede
#
#    State of Residence     Sex  Mobile Number (Preferably WhatsApp)  \
# 0                Ogun    Male                           9093934248
# ...

# %%
data_df["State of Residence"]=data_df["State of Residence"].replace({"LAGOS STATE":["Lagos"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Lagos state":["Lagos"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Lagos":["Lagos"]})
data_df
# Out:
#                      Email Address  First Name          Other Names  \
# 0       akinwamideelijah@gmail.com      Elijah           Akinwamide
# 1   ajayisegunsamuel2002@gmail.com    Olusegun               Samuel
# 2        akintundeakinba@gmail.com  Akinbamowo            Akintunde
# 3     johnsonchidinma304@gmail.com     Johnson         Chidinma joy
# 4          arewaolawale2@gmail.com       Arewa              Olawale
# ..                             ...         ...                  ...
# 66      adeoluwatomisin2@gmail.com     Adeniyi  Oluwatomisin kayode
# 67       ogunkandevictor@gmail.com   Ogunkande         Victor segun
# 68         Petertomywa72@gmail.com   Ogunmola                Peter
# 69       Basaumariam0000@gmail.com      Mariam             Precious
# 70         Hosannahomole@gmail.com    Hosannah               Korede
#
#    State of Residence     Sex  Mobile Number (Preferably WhatsApp)  \
# 0                Ogun    Male                           9093934248
# ...

# %%
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ekiti state":["Ekiti"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ekiti State":["Ekiti"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Tipper Garage mowe-ofadae":["Ekiti"]})
data_df
# Out:
#                      Email Address  First Name          Other Names  \
# 0       akinwamideelijah@gmail.com      Elijah           Akinwamide
# 1   ajayisegunsamuel2002@gmail.com    Olusegun               Samuel
# 2        akintundeakinba@gmail.com  Akinbamowo            Akintunde
# 3     johnsonchidinma304@gmail.com     Johnson         Chidinma joy
# 4          arewaolawale2@gmail.com       Arewa              Olawale
# ..                             ...         ...                  ...
# 66      adeoluwatomisin2@gmail.com     Adeniyi  Oluwatomisin kayode
# 67       ogunkandevictor@gmail.com   Ogunkande         Victor segun
# 68         Petertomywa72@gmail.com   Ogunmola                Peter
# 69       Basaumariam0000@gmail.com      Mariam             Precious
# 70         Hosannahomole@gmail.com    Hosannah               Korede
#
#    State of Residence     Sex  Mobile Number (Preferably WhatsApp)  \
# 0                Ogun    Male                           9093934248
# ...

# %%
data_df
# Out:
#                      Email Address  First Name          Other Names  \
# 0       akinwamideelijah@gmail.com      Elijah           Akinwamide
# 1   ajayisegunsamuel2002@gmail.com    Olusegun               Samuel
# 2        akintundeakinba@gmail.com  Akinbamowo            Akintunde
# 3     johnsonchidinma304@gmail.com     Johnson         Chidinma joy
# 4          arewaolawale2@gmail.com       Arewa              Olawale
# ..                             ...         ...                  ...
# 66      adeoluwatomisin2@gmail.com     Adeniyi  Oluwatomisin kayode
# 67       ogunkandevictor@gmail.com   Ogunkande         Victor segun
# 68         Petertomywa72@gmail.com   Ogunmola                Peter
# 69       Basaumariam0000@gmail.com      Mariam             Precious
# 70         Hosannahomole@gmail.com    Hosannah               Korede
#
#    State of Residence     Sex  Mobile Number (Preferably WhatsApp)  \
# 0                Ogun    Male                           9093934248
# ...

# %%
data_df["State of Residence"]=data_df["State of Residence"].replace({"Tipper Garage mowe-ofada, ogun state":["Ogun"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"OGUN":["Ogun"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ogun state":["Ogun"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ifo ogun state":["Ogun"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ogum":["Ogun"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ogun state ":["Ogun"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ilesha":["Osun"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Kwara state":["Kwara"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Rivers State":["Rivers"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Lagos ":["Lagos"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Oyo state ":["Oyo"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Ekiti State ":["Ekiti"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Osun state":["Osun"]})
data_df["State of Residence"]=data_df["State of Residence"].replace({"Kogi ":["Kogi"]})

# %%
data_df["State of Residence"].unique()
# Out:
# array(['Ogun', 'Lagos', 'Ondo', 'Kwara', 'Oyo', 'Osun', 'Ekiti', 'Kogi',
#        'Abuja', 'Oyo state', 'Benin Republic', 'Rivers'], dtype=object)

# %%
data_df
# Out:
#                      Email Address  First Name          Other Names  \
# 0       akinwamideelijah@gmail.com      Elijah           Akinwamide
# 1   ajayisegunsamuel2002@gmail.com    Olusegun               Samuel
# 2        akintundeakinba@gmail.com  Akinbamowo            Akintunde
# 3     johnsonchidinma304@gmail.com     Johnson         Chidinma joy
# 4          arewaolawale2@gmail.com       Arewa              Olawale
# ..                             ...         ...                  ...
# 66      adeoluwatomisin2@gmail.com     Adeniyi  Oluwatomisin kayode
# 67       ogunkandevictor@gmail.com   Ogunkande         Victor segun
# 68         Petertomywa72@gmail.com   Ogunmola                Peter
# 69       Basaumariam0000@gmail.com      Mariam             Precious
# 70         Hosannahomole@gmail.com    Hosannah               Korede
#
#    State of Residence     Sex  Mobile Number (Preferably WhatsApp)  \
# 0                Ogun    Male                           9093934248
# ...

# %%
data_df[data_df["Email Address"]=="hopeikuesan@gmail.com"]
# Out:
#             Email Address First Name Other Names State of Residence     Sex  \
# 22  hopeikuesan@gmail.com   Ikuesan        Hope               Lagos  Female
#
#     Mobile Number (Preferably WhatsApp)              Denomination  \
# 22                           7017955647  Deeper Life Bible Church
#
#    School/Faculty Applied For Course/Department Applied For  Jamb Score  ...  \
# 22   School of Sciences (SOS)                   Statistics          294  ...
#
#    Have you completed the online registration for the Post Utme Exam?  \
# 22                                                Yes
#
#    What challenge(s) are/were you faced with during the cause of application and registration?  \
# 22                                               None
#
#       How can we help you?  \
# 22  No help needed for now
#
#    What are your expectations from DLCF FUTA as regards your preparations for the Post Utme Test?  \
# 22  I expect DLCF FUTA to guide me to the best of ...
#
# ...

# %%
data_df["Denomination"].unique()
# Out:
# array(['Deeper Life Bible Church', 'CAC', 'RCCG',
#        'Christian Faith World Outreach Centre (INC)',
#        'Christ apostolic church', 'C&s', 'Winners', 'Tacfon',
#        'Christ Apostolic Church', 'Apostolic faith church',
#        'The Apostolic church', 'C.A.C',
#        'The Redeemed Christian Church of God ',
#        'The Redeemed Christian Church of God',
#        'mountain of fire and miracles ministries', 'Catholic Church ',
#        'The Redeem Christian Church Of God', 'TACN', 'IGEM ccc',
#        'Christ second Coming Gospel assembly osun state',
#        'Christ Trumpeters Church', 'Christ Apostolic Church ',
#        'Anglican Communion', 'MFM', "Abundant Grace Ministry Int'l.",
#        'Anglican', 'Redeem christian church of God ',
#        'Jesus christ life gospel church',
#        ' Reedeem Christian Church of God',
#        'Redeemed Christian Church of God'], dtype=object)

# %%
data_df["Denomination"]=data_df["Denomination"].replace({"Deeper Life Bible Church":["DLBC"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Christian Faith World Outreach Centre (INC)":["CFWOC"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Christ apostolic church":["CAC"]})
data_df["Denomination"]=data_df["Denomination"].replace({"C.A.C":["CAC"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Reedeem Christian Church of God":["RCCG"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Reedeem Christian Church of God ":["RCCG"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Christ second Coming Gospel assembly osun state":["CSCGA"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Christ Apostolic Church":["CAC"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Christ Trumpeters Church":["CTC"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Anglican Communion":["AC"]})
data_df["Denomination"]=data_df["Denomination"].replace({"mountain of fire and miracles ministries":["MFM"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Abundant Grace Ministry Int'l.":["AGMI"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Jesus christ life gospel church":["JCLGC"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Catholic Church ":["CC"]})
data_df["Denomination"]=data_df["Denomination"].replace({"IGEM ccc":["IGEM"]})
data_df["Denomination"]=data_df["Denomination"].replace({"The Redeem Christian Church Of God":["RCCG"]})
data_df["Denomination"]=data_df["Denomination"].replace({"The Redeemed Christian Church of God ":["RCCG"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Redeem christian church of God":["RCCG"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Redeemed Christian Church of God":["RCCG"]})
data_df["Denomination"]=data_df["Denomination"].replace({" Reedeem Christian Church of God":["RCCG"]})
data_df["Denomination"]=data_df["Denomination"].replace({"The Redeemed Christian Church of God":["RCCG"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Apostolic faith church":["AFC"]})
data_df["Denomination"]=data_df["Denomination"].replace({"The Apostolic church":["AFC"]})
data_df["Denomination"]=data_df["Denomination"].replace({"Christ Apostolic Church ":["CAC"]})

# %%
data_df["Denomination"].unique()
# Out:
# array(['DLBC', 'CAC', 'RCCG', 'CFWOC', 'C&s', 'Winners', 'Tacfon', 'AFC',
#        'MFM', 'CC', 'TACN', 'IGEM', 'CSCGA', 'CTC', 'AC', 'AGMI',
#        'Anglican', 'Redeem christian church of God ', 'JCLGC'],
#       dtype=object)

# %%
data_df
# Out:
#                      Email Address  First Name          Other Names  \
# 0       akinwamideelijah@gmail.com      Elijah           Akinwamide
# 1   ajayisegunsamuel2002@gmail.com    Olusegun               Samuel
# 2        akintundeakinba@gmail.com  Akinbamowo            Akintunde
# 3     johnsonchidinma304@gmail.com     Johnson         Chidinma joy
# 4          arewaolawale2@gmail.com       Arewa              Olawale
# ..                             ...         ...                  ...
# 66      adeoluwatomisin2@gmail.com     Adeniyi  Oluwatomisin kayode
# 67       ogunkandevictor@gmail.com   Ogunkande         Victor segun
# 68         Petertomywa72@gmail.com   Ogunmola                Peter
# 69       Basaumariam0000@gmail.com      Mariam             Precious
# 70         Hosannahomole@gmail.com    Hosannah               Korede
#
#    State of Residence     Sex  Mobile Number (Preferably WhatsApp)  \
# 0                Ogun    Male                           9093934248
# ...

# %%
data_df["School/Faculty Applied For"].unique()
# Out:
# array(['School of Environmental  Technology (SET)',
#        'School of Engineering and Engineering Technology (SEET)',
#        'School of Sciences (SOS)', 'School of Computing (SOC)',
#        'School of Health and Health Technology (SHHT)',
#        'School of Agriculture and Agricultural Technology (SAAT)'],
#       dtype=object)

# %%
data_df["School/Faculty Applied For"]=data_df["School/Faculty Applied For"].replace({"School of Environmental  Technology (SET)":["SET"]})
data_df["School/Faculty Applied For"]=data_df["School/Faculty Applied For"].replace({"School of Engineering and Engineering Technology (SEET)":["SEET"]})
data_df["School/Faculty Applied For"]=data_df["School/Faculty Applied For"].replace({"School of Sciences (SOS)":["SOS"]})
data_df["School/Faculty Applied For"]=data_df["School/Faculty Applied For"].replace({"School of Computing (SOC)":["SOC"]})
data_df["School/Faculty Applied For"]=data_df["School/Faculty Applied For"].replace({"School of Health and Health Technology (SHHT)":["SHHT"]})
data_df["School/Faculty Applied For"]=data_df["School/Faculty Applied For"].replace({"School of Agriculture and Agricultural Technology (SAAT)":["SAAT"]})

# %%
data_df["School/Faculty Applied For"].unique()
# Out:
# array(['SET', 'SEET', 'SOS', 'SOC', 'SHHT', 'SAAT'], dtype=object)

# %%
data_df
# Out:
#                      Email Address  First Name          Other Names  \
# 0       akinwamideelijah@gmail.com      Elijah           Akinwamide
# 1   ajayisegunsamuel2002@gmail.com    Olusegun               Samuel
# 2        akintundeakinba@gmail.com  Akinbamowo            Akintunde
# 3     johnsonchidinma304@gmail.com     Johnson         Chidinma joy
# 4          arewaolawale2@gmail.com       Arewa              Olawale
# ..                             ...         ...                  ...
# 66      adeoluwatomisin2@gmail.com     Adeniyi  Oluwatomisin kayode
# 67       ogunkandevictor@gmail.com   Ogunkande         Victor segun
# 68         Petertomywa72@gmail.com   Ogunmola                Peter
# 69       Basaumariam0000@gmail.com      Mariam             Precious
# 70         Hosannahomole@gmail.com    Hosannah               Korede
#
#    State of Residence     Sex  Mobile Number (Preferably WhatsApp)  \
# 0                Ogun    Male                           9093934248
# ...

# %%
import numpy as np
data_df['Jambite highest score from each school'] = np.where(data_df.groupby('School/Faculty Applied For')['Jamb Score'].transform("max").eq(data_df['Jamb Score']), 'highest','')
data_df
# Out:
#                      Email Address  First Name          Other Names  \
# 0       akinwamideelijah@gmail.com      Elijah           Akinwamide
# 1   ajayisegunsamuel2002@gmail.com    Olusegun               Samuel
# 2        akintundeakinba@gmail.com  Akinbamowo            Akintunde
# 3     johnsonchidinma304@gmail.com     Johnson         Chidinma joy
# 4          arewaolawale2@gmail.com       Arewa              Olawale
# ..                             ...         ...                  ...
# 66      adeoluwatomisin2@gmail.com     Adeniyi  Oluwatomisin kayode
# 67       ogunkandevictor@gmail.com   Ogunkande         Victor segun
# 68         Petertomywa72@gmail.com   Ogunmola                Peter
# 69       Basaumariam0000@gmail.com      Mariam             Precious
# 70         Hosannahomole@gmail.com    Hosannah               Korede
#
#    State of Residence     Sex  Mobile Number (Preferably WhatsApp)  \
# 0                Ogun    Male                           9093934248
# ...

# %%
#Details of the highest jambite
data_df[data_df['Jamb Score'] == data_df['Jamb Score'].max()]
# Out:
#             Email Address First Name Other Names State of Residence     Sex  \
# 22  hopeikuesan@gmail.com   Ikuesan        Hope               Lagos  Female
#
#     Mobile Number (Preferably WhatsApp) Denomination  \
# 22                           7017955647         DLBC
#
#    School/Faculty Applied For Course/Department Applied For  Jamb Score  ...  \
# 22                        SOS                   Statistics          294  ...
#
#    What challenge(s) are/were you faced with during the cause of application and registration?  \
# 22                                               None
#
#       How can we help you?  \
# 22  No help needed for now
#
#    What are your expectations from DLCF FUTA as regards your preparations for the Post Utme Test?  \
# 22  I expect DLCF FUTA to guide me to the best of ...
#
#    Day Month  Year  Hour  Minute  Second  \
# 22  30    10  2020    17      36      32
#
#     Jambite highest score from each school
# ...

# %%
data_df[data_df['Jamb Score'] == data_df['Jamb Score'].max()]["First Name"]
# Out:
# 22    Ikuesan
# Name: First Name, dtype: object

# %%
data_df["First Name"].unique()
# Out:
# array(['Elijah', 'Olusegun', 'Akinbamowo', 'Johnson', 'Arewa', 'Adebambo',
#        'Bukunmi', 'DANIEL', 'Ayeni ', 'Shobayo', 'Joel', 'Israel',
#        'ILESANMi', 'BELLO ENOCH ', 'Odunayo', 'Ruth', 'Oyinlade',
#        'Gbolahan', 'Alabe', 'Fatimehin', 'Mercy ', 'Abel', 'Ikuesan ',
#        'Oladimeji', 'Adebola', 'Adeleye', 'David', 'Akinbo', 'Elizabeth',
#        'Ibrahim ', 'Samuel ', 'Akinrinade', 'Otaomokunola ', 'Ajiboye ',
#        'Olaleye', 'Akinola', 'Daniel', 'Adam', 'Goodluck ', 'Elemure ',
#        'Emmanuel', 'Eesuola', 'Priscilla', 'Abe', 'Samuel', 'Aribaba',
#        'Ireti-Oluwa', 'Kayode', 'Afolabi ', 'Olanipekun', 'Bakare',
#        'Omodadepo', 'philip', 'Oyedele', 'Paulinus', 'Anjorin',
#        'Olorunda', 'Akintade', 'Adepoju', 'Esther', 'Folorunsho', 'Jumbo',
#        'Akinfolahan', 'James', 'Adeniyi', 'Ogunkande', 'Ogunmola ',
#        'Mariam', 'Hosannah'], dtype=object)

# %%
data_df[data_df['Jamb Score'] == data_df['Jamb Score'].min()]
# Out:
#            Email Address First Name       Other Names State of Residence  \
# 27  mideayo306@gmail.com     Akinbo  Favour oluwakemi              Lagos
#
#        Sex  Mobile Number (Preferably WhatsApp) Denomination  \
# 27  Female                           8181276953          AFC
#
#    School/Faculty Applied For Course/Department Applied For  Jamb Score  ...  \
# 27                       SEET                  Architecture         184  ...
#
#    What challenge(s) are/were you faced with during the cause of application and registration?  \
# 27                     I haven't done my registration
#
#    How can we help you?  \
# 27   With my jamb score
#
#    What are your expectations from DLCF FUTA as regards your preparations for the Post Utme Test?  \
# 27  Solving post utme past questions together and ...
#
#    Day Month  Year  Hour  Minute  Second  \
# 27  30    10  2020    22      36      33
#
#     Jambite highest score from each school
# 27
#
# [1 rows x 23 columns]

# %%
# To get the highest jamb score from each schhol
data_df.groupby('School/Faculty Applied For').apply(lambda x: x[x['Jamb Score'] == x['Jamb Score'].max()])
# Out:
#                                               Email Address First Name  \
# School/Faculty Applied For
# SAAT                       28        abosedejoy13@gmail.com  Elizabeth
# SEET                       11     praiseayobamiji@gmail.com     Israel
# SET                        0     akinwamideelijah@gmail.com     Elijah
# SHHT                       21  abelsimiloluwa2001@gmail.com       Abel
# SOC                        4        arewaolawale2@gmail.com      Arewa
# SOS                        22         hopeikuesan@gmail.com   Ikuesan
#
#                                     Other Names State of Residence     Sex  \
# School/Faculty Applied For
# SAAT                       28  Olaniran Abosede              Kwara  Female
# SEET                       11     Oluwatumilara                Oyo    Male
# SET                        0         Akinwamide               Ogun    Male
# SHHT                       21             Ajayi              Lagos    Male
# ...

# %%
data_df
# Out:
#                      Email Address  First Name          Other Names  \
# 0       akinwamideelijah@gmail.com      Elijah           Akinwamide
# 1   ajayisegunsamuel2002@gmail.com    Olusegun               Samuel
# 2        akintundeakinba@gmail.com  Akinbamowo            Akintunde
# 3     johnsonchidinma304@gmail.com     Johnson         Chidinma joy
# 4          arewaolawale2@gmail.com       Arewa              Olawale
# ..                             ...         ...                  ...
# 66      adeoluwatomisin2@gmail.com     Adeniyi  Oluwatomisin kayode
# 67       ogunkandevictor@gmail.com   Ogunkande         Victor segun
# 68         Petertomywa72@gmail.com   Ogunmola                Peter
# 69       Basaumariam0000@gmail.com      Mariam             Precious
# 70         Hosannahomole@gmail.com    Hosannah               Korede
#
#    State of Residence     Sex  Mobile Number (Preferably WhatsApp)  \
# 0                Ogun    Male                           9093934248
# ...

# %%
data_df["Denomination"].unique()
data_df["Denomination"]=data_df["Denomination"].replace({"Redeem christian church of God ":["RCCG"]})

# %%
selected_columns=["First Name","State of Residence","Sex","Denomination","School/Faculty Applied For","Course/Department Applied For","Jamb Score","Day","Month","Year","Hour","Minute","Second"]

# %%
df=data_df[selected_columns].copy()
df
# Out:
#     First Name State of Residence     Sex Denomination  \
# 0       Elijah               Ogun    Male         DLBC
# 1     Olusegun              Lagos    Male         DLBC
# 2   Akinbamowo               Ondo    Male         DLBC
# 3      Johnson              Lagos  Female         DLBC
# 4        Arewa               Ondo    Male         DLBC
# ..         ...                ...     ...          ...
# 66     Adeniyi               Ondo    Male         RCCG
# 67   Ogunkande               Ondo    Male        JCLGC
# 68   Ogunmola               Lagos    Male         DLBC
# 69      Mariam               Ondo  Female         RCCG
# 70    Hosannah               Ondo    Male         RCCG
#
#    School/Faculty Applied For            Course/Department Applied For  \
# 0                         SET                             Architecture
# 1                        SEET       Electrical electronics engineering
# 2                        SEET                     Software engineering
# ...

# %%
df["Course/Department Applied For"].unique()
# Out:
# array(['Architecture', 'Electrical electronics engineering',
#        'Software engineering', 'Mathematics', 'Computer Science',
#        'Bio medical Technology', 'Mechanical engineering', 'Statistics',
#        'Computer engineering', 'Food science and technology',
#        'Human Anatomy', 'Mechanical Engineering ', 'EEE',
#        'Information technology ', 'Industrial production engineering',
#        'Urban and regional planning ', 'Biomedical technology',
#        'Biochemistry ', 'Statistics ',
#        'Agricultural and resources economics', 'Micro biology',
#        'Computer science', 'Industrial chemistry ',
#        'Software Engineering ', 'Computer Engineering',
#        'biomedical technology ', 'Mechanical Engineering', 'MEE',
#        'Estate management ', 'Biotechnology', 'Industrial mathematics ',
#        'CVE', 'Computer science ', 'Software engineering ',
#        'Biochemistry', 'Statics', 'Mechanical engineer', '268',
# ...

# %%
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"EEE":"Electrical Electronics Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Bio medical Technology":"Biomedical Technology"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Biomedical technology":"Biomedical Technology"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Mechanical engineering":"Mechanical Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Computer engineering":"Computer Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Architectural science":"Architecture"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Electrical and electronics engineering ":"Electrical Electronics Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Electrical engineering":"Electrical Electronics Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Software engineering":"Software Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Mechanical engineer":"Mechanical Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"MEE":"Mechanical Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Electrical electronics engineering":"Electrical Electronics Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Architecture ":"Architecture"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Biochemistry ":"Biochemistry"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Mechanical Engineering ":"Mechanical Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Statics":"Statistics"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"biomedical technology ":"Biomedical Technology"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Biotechnology":"Biomedical Technology"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"CVE":"Civil engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Electrical and electronics engineering":"Electrical Electronics Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Statistics ":"Statistics"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Computer science":"Computer Science"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Software engineering ":"Software Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Software Engineering ":"Software Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"Software Engineering ":"Software Engineering"})
df["Course/Department Applied For"]=df["Course/Department Applied For"].replace({"268":"Software Engineering"})

# %%
df.loc[50:70]
# Out:
#      First Name State of Residence     Sex Denomination  \
# 50   Olanipekun               Ogun  Female         DLBC
# 51       Bakare          Oyo state    Male       Tacfon
# 52    Omodadepo               Osun    Male          CTC
# 53       philip                Oyo    Male          CAC
# 54      Oyedele               Ogun    Male         DLBC
# 55     Paulinus     Benin Republic    Male         DLBC
# 56      Anjorin          Oyo state    Male           AC
# 57     Olorunda               Ondo  Female          MFM
# 58     Akintade               Ondo    Male         AGMI
# 59      Adepoju              Lagos    Male         DLBC
# 60       Esther              Lagos  Female         DLBC
# 61   Folorunsho              Lagos    Male         DLBC
# 62        Jumbo             Rivers    Male         DLBC
# 63  Akinfolahan               Ondo    Male     Anglican
# 64       Samuel               Ondo    Male         DLBC
# 65        James               Kogi    Male         DLBC
# ...

# %%
df[df["Year"]==2021]
# Out:
#      First Name State of Residence     Sex Denomination  \
# 57     Olorunda               Ondo  Female          MFM
# 58     Akintade               Ondo    Male         AGMI
# 59      Adepoju              Lagos    Male         DLBC
# 60       Esther              Lagos  Female         DLBC
# 61   Folorunsho              Lagos    Male         DLBC
# 62        Jumbo             Rivers    Male         DLBC
# 63  Akinfolahan               Ondo    Male     Anglican
# 64       Samuel               Ondo    Male         DLBC
# 65        James               Kogi    Male         DLBC
# 66      Adeniyi               Ondo    Male         RCCG
# 67    Ogunkande               Ondo    Male        JCLGC
# 68    Ogunmola               Lagos    Male         DLBC
# 69       Mariam               Ondo  Female         RCCG
# 70     Hosannah               Ondo    Male         RCCG
#
#    School/Faculty Applied For       Course/Department Applied For  Jamb Score  \
# ...

# %%
df[df["Year"]==2020]
# Out:
#        First Name State of Residence     Sex Denomination  \
# 0          Elijah               Ogun    Male         DLBC
# 1        Olusegun              Lagos    Male         DLBC
# 2      Akinbamowo               Ondo    Male         DLBC
# 3         Johnson              Lagos  Female         DLBC
# 4           Arewa               Ondo    Male         DLBC
# 5        Adebambo              Lagos    Male         DLBC
# 6         Bukunmi              Kwara    Male         DLBC
# 7          DANIEL               Ogun    Male         DLBC
# 8          Ayeni               Lagos    Male          CAC
# 9         Shobayo              Lagos    Male         RCCG
# 10           Joel              Lagos  Female         DLBC
# 11         Israel                Oyo    Male        CFWOC
# 12       ILESANMi               Ondo    Male         DLBC
# 13   BELLO ENOCH               Lagos    Male         DLBC
# 14        Odunayo               Osun    Male          CAC
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

# %%
plt.figure(figsize=(30,10))
ase=df["Day"].value_counts()
sns.barplot(x=ase.index,y=ase,)
plt.xlabel("Day")
plt.ylabel("Numbers")
font=200

# %%
fer=df["Sex"].value_counts(normalize=True,ascending=True)*100
plt.pie(fer,labels=fer.index,autopct="%1.1f%%",startangle=180)
plt.figure(figsize=(20,6))

# %%
plt.figure(figsize=(40,10))
ase=df["Day"]
sa=df["School/Faculty Applied For"]
sns.barplot(x=sa,y=ase)
plt.legend("Years")
plt.title("Days on which Jambites from each school wrote their Exams",fontsize=20)
plt.ylabel("Days")
plt.xlabel("School")
font=200

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Denomination",y="Jamb Score", hue="Sex", data=df)
# Out:
# <AxesSubplot:xlabel='Denomination', ylabel='Jamb Score'>

# %%
plt.figure(figsize=(12,6))
sd=df["Year"].value_counts(normalize=True,ascending=True)*100
plt.pie(sd,labels=sd.index, autopct="%1.1f%%", startangle=180)
plt.title("Percentage of the year of students register")
# Out:
# Text(0.5, 1.0, 'Percentage of the year of students register')

# %%
df["School/Faculty Applied For"].count()
# Out:
# 71

# %%
df["School/Faculty Applied For"].value_counts()
# Out:
# SEET    30
# SOS     15
# SHHT     9
# SET      8
# SOC      7
# SAAT     2
# Name: School/Faculty Applied For, dtype: int64

# %%
we=df["School/Faculty Applied For"].value_counts(normalize=True, ascending=True)*100
we
# Out:
# SAAT     2.816901
# SOC      9.859155
# SET     11.267606
# SHHT    12.676056
# SOS     21.126761
# SEET    42.253521
# Name: School/Faculty Applied For, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=we.index,y=we)
plt.title("Percentage of Students For Each School")
plt.xlabel("Percentage")
plt.ylabel("School")
# Out:
# Text(0, 0.5, 'School')

# %%
sd=df["State of Residence"].value_counts()
sd
# Out:
# Ondo              20
# Lagos             20
# Ogun               7
# Osun               5
# Ekiti              5
# Oyo                4
# Oyo state          3
# Kwara              2
# Kogi               2
# Abuja              1
# Benin Republic     1
# Rivers             1
# Name: State of Residence, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=sd.index, y=sd)
plt.title("Students State of Residence")
plt.ylabel("No. of Student from Each State")
plt.xlabel("States")
# Out:
# Text(0.5, 0, 'States')

# %%
fd=df["School/Faculty Applied For"].value_counts()
fd
# Out:
# SEET    30
# SOS     15
# SHHT     9
# SET      8
# SOC      7
# SAAT     2
# Name: School/Faculty Applied For, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=fd.index, y=fd)
plt.title("Number of students applied for each school")
plt.xlabel("School")
plt.ylabel("Number of students")
# Out:
# Text(0, 0.5, 'Number of students')

# %%
len(df[df["Denomination"]=="RCCG"])
# Out:
# 7

# %%
plt.figure(figsize=(20,10))
da=df["Denomination"].value_counts()
sns.barplot(x=da.index,y=da)
plt.title("Denomination of the Jambites")
plt.ylabel("Denomination")
plt.xlabel("Number of Jambites from each denomination")
#This means that we the highest jambites are from DLBC and it require proper check up on them so that they will no join other fellowship when they have been admitted#
# Out:
# Text(0.5, 0, 'Number of Jambites from each denomination')

# %%
plt.figure(figsize=(12,6))
sr=df["Jamb Score"]
we=df["School/Faculty Applied For"]
sns.barplot(x=we,y=sr)
plt.title("Jamb Score of Students From Each School Apllied For")
plt.xlabel("School")
# Out:
# Text(0.5, 0, 'School')

# %%
# i could not analyse this
plt.figure(figsize=(12,6))
sns.boxplot(x=we,y=sr)
# Out:
# <AxesSubplot:xlabel='School/Faculty Applied For', ylabel='Jamb Score'>

# %%
plt.figure(figsize=(20,10))
ws=df["Course/Department Applied For"].value_counts(normalize=True,ascending=True)*100
sns.barplot(x=ws,y=ws.index)
plt.title("Percentage of students register for each school")
plt.xlabel("Percentage")
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')
